# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
x = np.random.randint(200, 10000, 500)
y = np.random.randint(200,10000,500)

# %%
df = pd.DataFrame({'x': x, 'y': y})

# %%
df
# Out:
#         x     y
# 0    7541  7148
# 1    2130   913
# 2    6152  4219
# 3    6094  7725
# 4    7481  1112
# ..    ...   ...
# 495  7804  3298
# 496  3201  1506
# 497  2140  5289
# 498  6121  9714
# 499  2106  9609
#
# [500 rows x 2 columns]

# %%
alt.Chart(df).mark_point().encode(x='x', y='y').properties().interactive()
# Out:
# alt.Chart(...)
